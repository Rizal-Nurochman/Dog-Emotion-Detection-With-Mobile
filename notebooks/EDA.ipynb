# %% [markdown]
# ## Import Library

# %%
from pathlib import Path
from collections import Counter
from PIL import Image
import matplotlib.pyplot as plt
import yaml

CONFIG  = yaml.safe_load(Path("configs/config.yaml").read_text())
RAW_DIR = Path(CONFIG["data"]["raw_dir"])
CLASSES = CONFIG["data"]["classes"]
print("kelas:", CLASSES)
# Out:
# Running cells with 'Python 3.11.15' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/asusA/.local/bin/python3.11.exe -m pip install ipykernel -U --user --force-reinstall'
